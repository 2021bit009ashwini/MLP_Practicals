# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
dataset = pd.read_csv(r"C:\Users\ratho\Downloads\archive\Original_data_with_more_rows.csv")
df = pd.DataFrame(dataset)
df
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female     group B   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         995    male     group C    some high school      standard
# 30637         996    male     group E  associate's degree  free/reduced
# 30638         997    male     group C        some college      standard
# 30639         998    male     group A    some high school  free/reduced
# 30640         999  female     group D  associate's degree      standard
#
#         TestPrep  MathScore  ReadingScore  WritingScore
# ...

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
print(X)
# Out:
# [[0 'female' 'group B' ... 'none' 72 72]
#  [1 'female' 'group C' ... 'completed' 69 90]
#  [2 'female' 'group B' ... 'none' 90 95]
#  ...
#  [997 'male' 'group C' ... 'none' 36 29]
#  [998 'male' 'group A' ... 'completed' 43 34]
#  [999 'female' 'group D' ... 'none' 52 68]]

# %%
print(y)
# Out:
# [74 88 93 ... 27 39 66]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Gender          0
# EthnicGroup     0
# ParentEduc      0
# LunchType       0
# TestPrep        0
# MathScore       0
# ReadingScore    0
# WritingScore    0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Unnamed: 0      30641
# Gender          30641
# EthnicGroup     30641
# ParentEduc      30641
# LunchType       30641
# TestPrep        30641
# MathScore       30641
# ReadingScore    30641
# WritingScore    30641
# dtype: int64

# %%
df1 = df.copy()

# %%
print("Before:",df1.shape)
df1.dropna(inplace=True)
print("After:",df1.shape)
# Out:
# Before: (30641, 9)
# After: (30641, 9)

# %%
print(df1.shape)
# Out:
# (30641, 9)

# %%
df2 = df.copy()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df2.fillna(value=9, inplace=True)
print(df2.isnull().sum())
df2
# Out:
# Unnamed: 0      0
# Gender          0
# EthnicGroup     0
# ParentEduc      0
# LunchType       0
# TestPrep        0
# MathScore       0
# ReadingScore    0
# WritingScore    0
# dtype: int64
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female     group B   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         995    male     group C    some high school      standard
# 30637         996    male     group E  associate's degree  free/reduced
# 30638         997    male     group C        some college      standard
# ...

# %%
X
# Out:
# array([[0, 'female', 'group B', ..., 'none', 72, 72],
#        [1, 'female', 'group C', ..., 'completed', 69, 90],
#        [2, 'female', 'group B', ..., 'none', 90, 95],
#        ...,
#        [997, 'male', 'group C', ..., 'none', 36, 29],
#        [998, 'male', 'group A', ..., 'completed', 43, 34],
#        [999, 'female', 'group D', ..., 'none', 52, 68]], dtype=object)

# %%
y
# Out:
# array([74, 88, 93, ..., 27, 39, 66], dtype=int64)

# %%
df.isnull()
# Out:
#        Unnamed: 0  Gender  EthnicGroup  ParentEduc  LunchType  TestPrep  \
# 0           False   False        False       False      False     False
# 1           False   False        False       False      False     False
# 2           False   False        False       False      False     False
# 3           False   False        False       False      False     False
# 4           False   False        False       False      False     False
# ...           ...     ...          ...         ...        ...       ...
# 30636       False   False        False       False      False     False
# 30637       False   False        False       False      False     False
# 30638       False   False        False       False      False     False
# 30639       False   False        False       False      False     False
# 30640       False   False        False       False      False     False
#
#        MathScore  ReadingScore  WritingScore
# 0          False         False         False
# ...

# %%
pd.get_dummies(df.head())
# Out:
#    Unnamed: 0  MathScore  ReadingScore  WritingScore  Gender_female  \
# 0           0         72            72            74           True
# 1           1         69            90            88           True
# 2           2         90            95            93           True
# 3           3         47            57            44          False
# 4           4         76            78            75          False
#
#    Gender_male  EthnicGroup_group A  EthnicGroup_group B  EthnicGroup_group C  \
# 0        False                False                 True                False
# 1        False                False                False                 True
# 2        False                False                 True                False
# 3         True                 True                False                False
# 4         True                False                False                 True
#
#    ParentEduc_associate's degree  ParentEduc_bachelor's degree  \
# ...

# %%
dict={
 #list of dict
 'roll_no':[1,2,3,4,5,6],
 'name':['Ashwini','Sushant','Alice','Teesha','Kunal','Akash'],
 'marks':[98,98,56,86,84,88]
}
dict
# Out:
# {'roll_no': [1, 2, 3, 4, 5, 6],
#  'name': ['Ashwini', 'Sushant', 'Alice', 'Teesha', 'Kunal', 'Akash'],
#  'marks': [98, 98, 56, 86, 84, 88]}

# %%
dt=pd.DataFrame(dict)
print(dt)
# Out:
#    roll_no      name  marks
# 0        1  Avantika     98
# 1        2   Sushant     98
# 2        3     Alice     56
# 3        4    Teesha     86
# 4        5     Kunal     84
# 5        6     Akash     88

# %%
df3=df.copy()
df3
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female     group B   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         995    male     group C    some high school      standard
# 30637         996    male     group E  associate's degree  free/reduced
# 30638         997    male     group C        some college      standard
# 30639         998    male     group A    some high school  free/reduced
# 30640         999  female     group D  associate's degree      standard
#
#         TestPrep  MathScore  ReadingScore  WritingScore
# ...

# %%
df3['MathScore'].replace(72,100,inplace=True)
df3
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female     group B   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         995    male     group C    some high school      standard
# 30637         996    male     group E  associate's degree  free/reduced
# 30638         997    male     group C        some college      standard
# 30639         998    male     group A    some high school  free/reduced
# 30640         999  female     group D  associate's degree      standard
#
#         TestPrep  MathScore  ReadingScore  WritingScore
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df4=df.copy()
df4.interpolate(inplace=True)
df4
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female     group B   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         995    male     group C    some high school      standard
# 30637         996    male     group E  associate's degree  free/reduced
# 30638         997    male     group C        some college      standard
# 30639         998    male     group A    some high school  free/reduced
# 30640         999  female     group D  associate's degree      standard
#
#         TestPrep  MathScore  ReadingScore  WritingScore
# ...

# %%
df.isnull()
# Out:
#        Unnamed: 0  Gender  EthnicGroup  ParentEduc  LunchType  TestPrep  \
# 0           False   False        False       False      False     False
# 1           False   False        False       False      False     False
# 2           False   False        False       False      False     False
# 3           False   False        False       False      False     False
# 4           False   False        False       False      False     False
# ...           ...     ...          ...         ...        ...       ...
# 30636       False   False        False       False      False     False
# 30637       False   False        False       False      False     False
# 30638       False   False        False       False      False     False
# 30639       False   False        False       False      False     False
# 30640       False   False        False       False      False     False
#
#        MathScore  ReadingScore  WritingScore
# 0          False         False         False
# ...

# %%
df4[(df4['TestPrep']==64)&(df4['MathScore']==54)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Gender, EthnicGroup, ParentEduc, LunchType, TestPrep, MathScore, ReadingScore, WritingScore]
# Index: []

# %%
pd.get_dummies(df.head())
# Out:
#    Unnamed: 0  MathScore  ReadingScore  WritingScore  Gender_female  \
# 0           0         72            72            74           True
# 1           1         69            90            88           True
# 2           2         90            95            93           True
# 3           3         47            57            44          False
# 4           4         76            78            75          False
#
#    Gender_male  EthnicGroup_group A  EthnicGroup_group B  EthnicGroup_group C  \
# 0        False                False                 True                False
# 1        False                False                False                 True
# 2        False                False                 True                False
# 3         True                 True                False                False
# 4         True                False                False                 True
#
#    ParentEduc_associate's degree  ParentEduc_bachelor's degree  \
# ...
